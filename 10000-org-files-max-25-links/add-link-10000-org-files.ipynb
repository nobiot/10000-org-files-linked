# %%
import random
import os
path = "./10000-org-files"
limitForLinks = 25

# %%
def generateLinkString():
    filesToLink = random.choices(files, k=random.randrange(0,limitForLinks))
    str = ""
    for filename in filesToLink:
        filelink = "[[file:" + filename + "]]\n"
        str += filelink
    return str

# %%
files = os.listdir(path)

# %%
for fileToUpdate in files:
    file = open(os.path.join(path, fileToUpdate), "a")
    file.write(generateLinkString())
    file.close
    print(fileToUpdate + " done")
# Out:
# abdominous_reaction_formation.org done
# abducent_common_racoon.org done
# abducent_port_moresby.org done
# aberrant_suspiciousness.org done
# aberrant_xeranthemum_annuum.org done
# abiogenetic_nutlet.org done
# abkhazian_caucasoid_race.org done
# abkhazian_opcw.org done
# ablative_genus_euproctis.org done
# able-bodied_automatic_teller_machine.org done
# able_euphorbia_litchi.org done
# abnormal_grab_bar.org done
# abolitionary_annotation.org done
# abolitionary_christmas_holly.org done
# abomasal_tribology.org done
# abominable_lexington_and_concord.org done
# above-mentioned_cerise.org done
# aboveground_yelping.org done
# abranchial_radioactive_waste.org done
# abreast_princeton_university.org done
# abroach_shell_ginger.org done
# abroad_chocolate.org done
# abruptly-pinnate_menuridae.org done
# abscessed_bath_linen.org done
# absentminded_barbette.org done
# absolute_bubble_chamber.org done
# absolutistic_strikebreaking.org done
# absolutist_usaf.org done
# ...
